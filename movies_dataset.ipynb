# %% [markdown]
# <a href="https://colab.research.google.com/github/Milindkr/EDA_Projects/blob/main/movies_dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone "https://github.com/HarshvardhanSingh-13/Datasets"
# Out:
# Cloning into 'Datasets'...
# remote: Enumerating objects: 347, done.
# remote: Counting objects: 100% (105/105), done.
# remote: Compressing objects: 100% (90/90), done.
# remote: Total 347 (delta 25), reused 0 (delta 0), pack-reused 242 (from 1)
# Receiving objects: 100% (347/347), 302.89 MiB | 17.12 MiB/s, done.
# Resolving deltas: 100% (139/139), done.
# Updating files: 100% (245/245), done.

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/Datasets/IMDB Movies/movies.csv")

# %%
df.head()
# Out:
#            id                      name  year  rating certificate duration  \
# 0   tt0068646             The Godfather  1972     9.2           R  175 min
# 1   tt5113044  Minions: The Rise of Gru  2022     7.3          PG   87 min
# 2   tt7657566         Death on the Nile  2022     6.3       PG-13  127 min
# 3   tt8115900              The Bad Guys  2022     6.9          PG  100 min
# 4  tt10809742                 Collision  2022     3.8       TV-MA   99 min
#
#                           genre    votes gross_income  \
# 0                  Crime, Drama  1798749  134,966,411
# 1  Animation, Adventure, Comedy    1,220  134,966,411
# 2         Crime, Drama, Mystery  121,063  134,966,411
# 3  Animation, Adventure, Comedy   23,090  134,966,411
# 4        Crime, Drama, Thriller      656  134,966,411
#
#                     directors_id                            directors_name  \
# 0                      nm0000338                      Francis Ford Coppola
# ...

# %%
df.tail()
# Out:
#               id                                         name  year  rating  \
# 19803  tt0459423  Kahaani Gudiya Ki...: True Story of a Woman  2008     6.2
# 19804  tt0119621                      Mark Twain's America in  1998     6.5
# 19805  tt0168950    Let It Come Down: The Life of Paul Bowles  1998     6.9
# 19806  tt0267563                                       Hybrid  2000     7.4
# 19807  tt0116481         Hands on a Hardbody: The Documentary  1997     7.6
#
#       certificate duration                       genre votes gross_income  \
# 19803   Not Rated  112 min            Biography, Drama    41       44,435
# 19804           G   52 min      Documentary, Biography    48    2,281,741
# 19805   Not Rated   75 min      Documentary, Biography   125        9,188
# 19806   Not Rated   92 min      Documentary, Biography   146      159,403
# 19807          PG   98 min  Documentary, Comedy, Drama  2167      492,876
#
# ...

# %%
df.sample()
# Out:
#               id                                 name  year  rating  \
# 16669  tt0036112  The Life and Death of Colonel Blimp  1943     8.0
#
#       certificate duration                genre   votes gross_income  \
# 16669   Not Rated  163 min  Drama, Romance, War  14,787      372,755
#
#               directors_id                     directors_name  \
# 16669  nm0003836,nm0696247  Michael Powell,Emeric Pressburger
#
#                                       stars_id  \
# 16669  nm0515193,nm0000039,nm0906932,nm0571129
#
#                                               stars_name  \
# 16669  Roger Livesey,Deborah Kerr,Anton Walbrook,Jame...
#
#                                              description
# 16669  From the Boer War through World War II, a sold...

# %%
df.sample(5)
# Out:
#               id                               name  year  rating certificate  \
# 11406  tt0081187                   The Mountain Men  1980     6.3           R
# 6087   tt0265349             The Mothman Prophecies  2002     6.4       PG-13
# 6883   tt8332802                             Amulet  2020     4.8           R
# 10434  tt4633694  Spider-Man: Into the Spider-Verse  2018     8.4          PG
# 12470  tt0093596                             Nadine  1987     5.5          PG
#
#       duration                         genre   votes gross_income  \
# 11406  102 min            Adventure, Western   2,314      161,800
# 6087   119 min        Drama, Horror, Mystery   80259   35,746,370
# 6883    99 min               Horror, Mystery   3,653    5,165,432
# 10434  117 min  Animation, Action, Adventure  498218  190,241,310
# 12470   83 min      Comedy, Mystery, Romance    4062    5,669,831
#
#                         directors_id  \
# 11406                      nm0485889
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19808 entries, 0 to 19807
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              19808 non-null  object
#  1   name            19808 non-null  object
#  2   year            19808 non-null  int64
#  3   rating          19808 non-null  float64
#  4   certificate     19808 non-null  object
#  5   duration        19808 non-null  object
#  6   genre           19808 non-null  object
#  7   votes           19808 non-null  object
#  8   gross_income    19808 non-null  object
#  9   directors_id    19808 non-null  object
#  10  directors_name  19808 non-null  object
#  11  stars_id        19808 non-null  object
#  12  stars_name      19808 non-null  object
#  13  description     19808 non-null  object
# dtypes: float64(1), int64(1), object(12)
# memory usage: 2.1+ MB

# %% [markdown]
# - In the above "duration" Column it written as object but it should be in integers
# - "votes"
# - "gross_income"

# %%
df.describe()
# Out:
#                year        rating
# count  19808.000000  19808.000000
# mean    1995.546597      6.041973
# std       22.801725      1.206831
# min     1894.000000      1.100000
# 25%     1983.000000      5.300000
# 50%     2003.000000      6.200000
# 75%     2014.000000      6.900000
# max     2022.000000      9.700000

# %%
df.isnull()
# Out:
#           id   name   year  rating  certificate  duration  genre  votes  \
# 0      False  False  False   False        False     False  False  False
# 1      False  False  False   False        False     False  False  False
# 2      False  False  False   False        False     False  False  False
# 3      False  False  False   False        False     False  False  False
# 4      False  False  False   False        False     False  False  False
# ...      ...    ...    ...     ...          ...       ...    ...    ...
# 19803  False  False  False   False        False     False  False  False
# 19804  False  False  False   False        False     False  False  False
# 19805  False  False  False   False        False     False  False  False
# 19806  False  False  False   False        False     False  False  False
# 19807  False  False  False   False        False     False  False  False
#
#        gross_income  directors_id  directors_name  stars_id  stars_name  \
# ...

# %%
df.isnull().sum()
# Out:
# id                0
# name              0
# year              0
# rating            0
# certificate       0
# duration          0
# genre             0
# votes             0
# gross_income      0
# directors_id      0
# directors_name    0
# stars_id          0
# stars_name        0
# description       0
# dtype: int64

# %% [markdown]
# What if I want to see rating column

# %%
df["rating"]
# Out:
# 0        9.2
# 1        7.3
# 2        6.3
# 3        6.9
# 4        3.8
#         ...
# 19803    6.2
# 19804    6.5
# 19805    6.9
# 19806    7.4
# 19807    7.6
# Name: rating, Length: 19808, dtype: float64

# %% [markdown]
# What if I want to see average/mean of the rating

# %%
df["rating"].mean()
# Out:
# np.float64(6.041972940226171)

# %% [markdown]
# What is I want to see median and mode

# %%
df['rating'].median()
# Out:
# 6.2

# %%
df["rating"].mode()
# Out:
# 0    6.4
# Name: rating, dtype: float64

# %%
# rating > 4

df["rating"] > 4  #You see It shows boolean value but we want data
# Out:
# 0         True
# 1         True
# 2         True
# 3         True
# 4        False
#          ...
# 19803     True
# 19804     True
# 19805     True
# 19806     True
# 19807     True
# Name: rating, Length: 19808, dtype: bool

# %%
#  df["rating"] > 4  -You see It shows boolean value but we want data then what we do

df[df["rating"] > 4]  # -- Now we get the data
# Out:
#               id                                         name  year  rating  \
# 0      tt0068646                                The Godfather  1972     9.2
# 1      tt5113044                     Minions: The Rise of Gru  2022     7.3
# 2      tt7657566                            Death on the Nile  2022     6.3
# 3      tt8115900                                 The Bad Guys  2022     6.9
# 5      tt0071562                        The Godfather Part II  1974     9.0
# ...          ...                                          ...   ...     ...
# 19803  tt0459423  Kahaani Gudiya Ki...: True Story of a Woman  2008     6.2
# 19804  tt0119621                      Mark Twain's America in  1998     6.5
# 19805  tt0168950    Let It Come Down: The Life of Paul Bowles  1998     6.9
# 19806  tt0267563                                       Hybrid  2000     7.4
# 19807  tt0116481         Hands on a Hardbody: The Documentary  1997     7.6
#
# ...

# %%
df["rating"].min()
# Out:
# 1.1

# %%
df["rating"].max()
# Out:
# 9.7

# %%
df["rating"].astype(int)
# Out:
# 0        9
# 1        7
# 2        6
# 3        6
# 4        3
#         ..
# 19803    6
# 19804    6
# 19805    6
# 19806    7
# 19807    7
# Name: rating, Length: 19808, dtype: int64

# %% [markdown]
# # Cleaning Part
#
# ### I have to clean
#
# - "duration"
# - "votes"
# - "gross_income"

# %% [markdown]
# ## Work on duration Column

# %%
df["duration"]
# Out:
# 0        175 min
# 1         87 min
# 2        127 min
# 3        100 min
# 4         99 min
#           ...
# 19803    112 min
# 19804     52 min
# 19805     75 min
# 19806     92 min
# 19807     98 min
# Name: duration, Length: 19808, dtype: object

# %%
df["duration"].astype(int)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_867/3046638452.py in <cell line: 0>()
# ----> 1 df["duration"].astype(int)
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/generic.py in astype(self, dtype, copy, errors)
#    6641         else:
#    6642             # else, only a single dtype is given
# -> 6643             new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644             res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645             return res.__finalize__(self, method="astype")
#
# /usr/local/lib/python3.12/dist-packages/pandas/core/internals/managers.py in astype(self, dtype, copy, errors)
#     428             copy = False
#     429
# --> 430         return self.apply(
#     431             "astype",
#     432             dtype=dtype,
#
# ...

# %%
# Now what to do is first convort it into string(str) then do operations of string like split()



# Step - 1



df["duration"].str.split()
# Out:
# 0        [175, min]
# 1         [87, min]
# 2        [127, min]
# 3        [100, min]
# 4         [99, min]
#             ...
# 19803    [112, min]
# 19804     [52, min]
# 19805     [75, min]
# 19806     [92, min]
# 19807     [98, min]
# Name: duration, Length: 19808, dtype: object

# %%
# Step - 2

df["duration"].str.replace("min","")

# Now it actually not replacing on the main column so for replacing this what do is
# Out:
# 0        175
# 1         87
# 2        127
# 3        100
# 4         99
#          ...
# 19803    112
# 19804     52
# 19805     75
# 19806     92
# 19807     98
# Name: duration, Length: 19808, dtype: object

# %%
# Step -3

df["duration"] = df["duration"].str.replace("min","")

# %%
# Step - 4

df["duration"] = df["duration"].str.replace(",","")

# %%
df["duration"]
# Out:
# 0        175
# 1         87
# 2        127
# 3        100
# 4         99
#          ...
# 19803    112
# 19804     52
# 19805     75
# 19806     92
# 19807     98
# Name: duration, Length: 19808, dtype: object

# %%
df["duration"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 19808 entries, 0 to 19807
# Series name: duration
# Non-Null Count  Dtype
# --------------  -----
# 19808 non-null  object
# dtypes: object(1)
# memory usage: 154.9+ KB

# %%
# Now we want to chnage the dataType of this

# Step - 5

df["duration"].astype(int)
# Out:
# 0        175
# 1         87
# 2        127
# 3        100
# 4         99
#         ...
# 19803    112
# 19804     52
# 19805     75
# 19806     92
# 19807     98
# Name: duration, Length: 19808, dtype: int64

# %%
# For Parmanetally chnage

# Step - 6

df["duration"] = df["duration"].astype(int)

# %%
# Show

df["duration"].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 19808 entries, 0 to 19807
# Series name: duration
# Non-Null Count  Dtype
# --------------  -----
# 19808 non-null  int64
# dtypes: int64(1)
# memory usage: 154.9 KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19808 entries, 0 to 19807
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              19808 non-null  object
#  1   name            19808 non-null  object
#  2   year            19808 non-null  int64
#  3   rating          19808 non-null  float64
#  4   certificate     19808 non-null  object
#  5   duration        19808 non-null  int64
#  6   genre           19808 non-null  object
#  7   votes           19808 non-null  object
#  8   gross_income    19808 non-null  object
#  9   directors_id    19808 non-null  object
#  10  directors_name  19808 non-null  object
#  11  stars_id        19808 non-null  object
#  12  stars_name      19808 non-null  object
#  13  description     19808 non-null  object
# dtypes: float64(1), int64(2), object(11)
# memory usage: 2.1+ MB

# %% [markdown]
# ## Work on Votes Column

# %%
df.head()
# Out:
#            id                      name  year  rating certificate  duration  \
# 0   tt0068646             The Godfather  1972     9.2           R       175
# 1   tt5113044  Minions: The Rise of Gru  2022     7.3          PG        87
# 2   tt7657566         Death on the Nile  2022     6.3       PG-13       127
# 3   tt8115900              The Bad Guys  2022     6.9          PG       100
# 4  tt10809742                 Collision  2022     3.8       TV-MA        99
#
#                           genre    votes gross_income  \
# 0                  Crime, Drama  1798749  134,966,411
# 1  Animation, Adventure, Comedy    1,220  134,966,411
# 2         Crime, Drama, Mystery  121,063  134,966,411
# 3  Animation, Adventure, Comedy   23,090  134,966,411
# 4        Crime, Drama, Thriller      656  134,966,411
#
#                     directors_id                            directors_name  \
# 0                      nm0000338                      Francis Ford Coppola
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19808 entries, 0 to 19807
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              19808 non-null  object
#  1   name            19808 non-null  object
#  2   year            19808 non-null  int64
#  3   rating          19808 non-null  float64
#  4   certificate     19808 non-null  object
#  5   duration        19808 non-null  int64
#  6   genre           19808 non-null  object
#  7   votes           19808 non-null  object
#  8   gross_income    19808 non-null  object
#  9   directors_id    19808 non-null  object
#  10  directors_name  19808 non-null  object
#  11  stars_id        19808 non-null  object
#  12  stars_name      19808 non-null  object
#  13  description     19808 non-null  object
# dtypes: float64(1), int64(2), object(11)
# memory usage: 2.1+ MB

# %%
df["votes"] = df["votes"].str.replace(",","")

# %%
df["votes"] = df["votes"].astype(int)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19808 entries, 0 to 19807
# Data columns (total 14 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   id              19808 non-null  object
#  1   name            19808 non-null  object
#  2   year            19808 non-null  int64
#  3   rating          19808 non-null  float64
#  4   certificate     19808 non-null  object
#  5   duration        19808 non-null  int64
#  6   genre           19808 non-null  object
#  7   votes           19808 non-null  int64
#  8   gross_income    19808 non-null  object
#  9   directors_id    19808 non-null  object
#  10  directors_name  19808 non-null  object
#  11  stars_id        19808 non-null  object
#  12  stars_name      19808 non-null  object
#  13  description     19808 non-null  object
# dtypes: float64(1), int64(3), object(10)
# memory usage: 2.1+ MB

# %%
df.loc[0]
# Out:
# id                                                        tt0068646
# name                                                  The Godfather
# year                                                           1972
# rating                                                          9.2
# certificate                                                       R
# duration                                                        175
# genre                                                  Crime, Drama
# votes                                                       1798749
# gross_income                                            134,966,411
# directors_id                                              nm0000338
# directors_name                                 Francis Ford Coppola
# stars_id                    nm0000008,nm0000199,nm0001001,nm0000473
# stars_name          Marlon Brando,Al Pacino,James Caan,Diane Keaton
# description       The aging patriarch of an organized crime dyna...
# ...

# %%
df.loc[[0, 1]]
# Out:
#           id                      name  year  rating certificate  duration  \
# 0  tt0068646             The Godfather  1972     9.2           R       175
# 1  tt5113044  Minions: The Rise of Gru  2022     7.3          PG        87
#
#                           genre    votes gross_income  \
# 0                  Crime, Drama  1798749  134,966,411
# 1  Animation, Adventure, Comedy     1220  134,966,411
#
#                     directors_id                            directors_name  \
# 0                      nm0000338                      Francis Ford Coppola
# 1  nm0049633,nm1556070,nm3646390  Kyle Balda,Brad Ableson,Jonathan del Val
#
#                                   stars_id  \
# 0  nm0000008,nm0000199,nm0001001,nm0000473
# 1  nm0136797,nm1853544,nm0000273,nm0378245
#
#                                           stars_name  \
# 0    Marlon Brando,Al Pacino,James Caan,Diane Keaton
# 1  Steve Carell,Pierre Coffin,Alan Arkin,Taraji P...
#
# ...
